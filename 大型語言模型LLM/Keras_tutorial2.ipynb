# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(512, activation='relu', input_dim=784))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

import numpy as np
data = np.random.random((1000, 784))
labels = np.random.randint(10, size=(1000, 10))

model.fit(data, labels, epochs=10, batch_size=32)

score=model.evaluate(data, labels)
print(score[1])
# Out:
# Epoch 1/10
# 32/32 [==============================] - 6s 3ms/step - loss: 353.4058 - accuracy: 0.1240
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 1145.7914 - accuracy: 0.1210
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 2177.7234 - accuracy: 0.1110
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 3424.9141 - accuracy: 0.1150
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4385.7363 - accuracy: 0.1110
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 5420.0718 - accuracy: 0.1250
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 6196.1587 - accuracy: 0.1070
# Epoch 8/10
# 32/32 [==============================] - 0s 3ms/step - loss: 7391.3970 - accuracy: 0.1100
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 8380.6240 - accuracy: 0.1190
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 9234.8525 - accuracy: 0.1260
# 32/32 [==============================] - 0s 3ms/step - loss: 8232.3643 - accuracy: 0.1200
# 0.11999999731779099
