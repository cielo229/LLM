# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten

mnist=keras.datasets.mnist
(train_data, train_label), (test_data, test_label) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print(type(train_data))
print(train_data.shape)
print(type(train_label))
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)

# %%
print(train_label[0])
print(train_data[0])

# %%
import matplotlib.pyplot as plt
plt.imshow(train_data[0], cmap='binary')
plt.show()

# %%
model=Sequential()
model.add(Flatten())
model.add(Dense(32, activation='relu', input_dim=784))
model.add(Dense(10, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(train_data,train_label,epochs=10)

score=model.evaluate(test_data, test_label)
print(score[1])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 3ms/step - loss: 1.8599 - accuracy: 0.7548
# Epoch 2/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6116 - accuracy: 0.8848
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5356 - accuracy: 0.9006
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4896 - accuracy: 0.9098
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4535 - accuracy: 0.9169
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4154 - accuracy: 0.9220
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3861 - accuracy: 0.9274
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3759 - accuracy: 0.9278
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3700 - accuracy: 0.9298
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3501 - accuracy: 0.9323
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6600 - accuracy: 0.9207
# 0.9207000136375427
